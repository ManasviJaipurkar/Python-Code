# %% [markdown]
# ## Simple hello world

# %%
#This is the comment
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ## Multiple way to print

# %%
print("Hello world")

message = "Hello World"
print(message)

print("Hello , World!")

name ="Python"
print(f"Hello,{name}")
# Out:
# Hello world
# Hello World
# Hello , World!
# Hello,Python
