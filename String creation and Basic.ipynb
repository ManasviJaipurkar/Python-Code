# %% [markdown]
# ## String creation and Basic

# %%
single_quotes = 'Hello'
double_quotes = "World"
triple_quotes = ''' THis is a multi-
line 
string'''
triple_double = """Another way 
to 
write
multi
line 
strin"""

# %%
print("STRING CREATION METHODS:")
print(f"single quotes: {single_quotes}\n")
print(f"double quotes: {double_quotes}\n")
print(f"triple quotes: {triple_quotes}\n")
print(f"triple double: {triple_double}")
# Out:
# STRING CREATION METHODS:
# single quotes: Hello
#
# double quotes: World
#
# triple quotes:  THis is a multi-
# line
# string
#
# triple double: Another way
# to
# write
# multi
# line
# strin

# %%
## string with special characters
print("\nSpecial character:")
print("Tab: Hello\tworld")
print("New line: Hello\nworld")
print("Backslash: This is a blackslash: \\")
# Out:
# Special character:
# Tab: Hello	world
# New line: Hello
# world
# Backslash: This is a blackslash: \
