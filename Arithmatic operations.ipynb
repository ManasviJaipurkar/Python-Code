# %%
a = 10
b = 3
print(f"Addition: {a} + {b} = {a+b}")
print(f"Addition: {a} - {b} = {a-b}")
print(f"Addition: {a} * {b} = {a*b}")
print(f"Addition: {a} / {b} = {a/b}")
print(f"Addition: {a} // {b} = {a//b}")
print(f"Addition: {a} % {b} = {a%b}")
print(f"Addition: {a} ** {b} = {a**b}")
# Out:
# Addition: 10 + 3 = 13
# Addition: 10 - 3 = 7
# Addition: 10 * 3 = 30
# Addition: 10 / 3 = 3.3333333333333335
# Addition: 10 // 3 = 3
# Addition: 10 % 3 = 1
# Addition: 10 ** 3 = 1000
